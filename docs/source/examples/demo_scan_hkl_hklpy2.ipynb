# %% [markdown]
# # WIP: Scan in $(hkl)$ coordinates
#
# This notebook demonstrates how to scan in $(hkl)$ coordinates. It uses the
# simulated 4-circle geometry from the `"hkl_soleil"` solver. The wavelength and
# sample are whatever the simulator provides as defaults.
#
# **Important**:  It is possible to scan in any combination of reciprocal axes or to
# scan in any combination of real-space axes.  You are not allowed to scan in a
# mix of reciprocal and real-space axes.
#
# ## Setup
#
# First, create the simulated 4-circle diffractometer object (`e4cv`).

# %%
from hklpy2 import SimulatedE4CV

e4cv = SimulatedE4CV(name="e4cv")

# %% [markdown]
# Setup Bluesky for running the scans with the `RE` object.  The `bec` object will
# show a table of the data collected for each scan.
#
# For this simple demonstration, we won't add a databroker catalog.

# %%
from bluesky import RunEngine, plans as bp
from bluesky.callbacks.best_effort import BestEffortCallback

bec = BestEffortCallback()
RE = RunEngine()
RE.subscribe(bec)
bec.disable_plots()

# %% [markdown]
# We'll **import a simulator** (ready to use) from the `ophyd` package as a noisy detector.

# %%
from ophyd.sim import noisy_det

# %% [markdown]
# ## (h10) scan
#
# Scan the (reciprocal space) $h$ axis from -0.5 to +0.5 with $k=1$ and $l=0$.
# This is called an $(h10)$ scan.
#
# <details>
#
# The computation to convert reciprocal-space values $(h,k,l)$ into real-space
# angles ($\omega$, $\chi$, $\phi$, $2\theta$) is called the `forward()`
# transformation.  The transformation is not necessarily unique.  The most common
# way to reduce the number of *solutions* is to tell the solver which `mode` to
# use.  The `mode` adds an additional pre-designed rule that constrains the
# acceptable solutions.  The solver's geometry (in this case `E4CV`) provides the
# list of known modes.
#
# Note: Even with a chosen mode, the solution might not be unique.  In such cases,
# the first solution returned by the `forward()` transformation is chosen.  The
# user can change this by providing a different function for the diffractometer's
# `_forward_solution` attribute.  The default is the
# `hklpy2.diffract.pick_first_item()` function.
#
# </details>
#
# Here, the diffractometer starts with `"bissector"` mode (requires `tth = 2*omega`).

# %%
print(f"{e4cv.operator.solver.mode=!r}")
e4cv.k.move(1)
e4cv.l.move(0)
RE(bp.scan([noisy_det], e4cv.h, -0.5, 0.5, 11))
# Out:
# e4cv.operator.solver.mode='bissector'
#
#
# Transient Scan ID: 1     Time: 2024-07-29 10:45:44
# Persistent Unique Scan ID: 'a66f79a6-96cb-441d-a5aa-71e2328fc68c'
# New stream: 'primary'
# +-----------+------------+------------+------------+
# |   seq_num |       time |     e4cv_h |  noisy_det |
# +-----------+------------+------------+------------+
# |         1 | 10:45:44.2 |     -0.500 |      0.996 |
# |         2 | 10:45:44.2 |     -0.400 |      0.985 |
# |         3 | 10:45:44.2 |     -0.300 |      1.049 |
# |         4 | 10:45:44.2 |     -0.200 |      0.980 |
# |         5 | 10:45:44.2 |     -0.100 |      1.032 |
# |         6 | 10:45:44.2 |      0.000 |      0.966 |
# |         7 | 10:45:44.2 |      0.100 |      0.969 |
# |         8 | 10:45:44.2 |      0.200 |      1.014 |
# |         9 | 10:45:44.3 |      0.300 |      0.911 |
# |        10 | 10:45:44.3 |      0.400 |      0.952 |
# |        11 | 10:45:44.3 |      0.500 |      1.020 |
# +-----------+------------+------------+------------+
# generator scan ['a66f79a6'] (scan num: 1)
# ('a66f79a6-96cb-441d-a5aa-71e2328fc68c',)

# %% [markdown]
# **Clearly we see** that $h$ has been stepped across the range of -0.5 to +0.5.
# Values for the noisy detector have been reported at each step.  But we want to
# know about *all* the $hkl$ and angle values so we can observe the effects of
# `"bissector"` mode.
#
# ### Scan again, showing all $(hkl)$ and real-space axes
#
# Repeat the scan, same as before with a slight variation.  This time, add the
# `e4cv` object as an additional detector.

# %%
print(f"{e4cv.operator.solver.mode=!r}")
e4cv.k.move(1)
e4cv.l.move(0)
RE(bp.scan([noisy_det, e4cv], e4cv.h, -0.5, 0.5, 11))
# Out:
# e4cv.operator.solver.mode='bissector'
#
#
# Transient Scan ID: 2     Time: 2024-07-29 10:45:44
# Persistent Unique Scan ID: '78c80bd6-ebed-45c5-866d-14f05769844f'
# New stream: 'primary'
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |   seq_num |       time |     e4cv_h |  noisy_det |     e4cv_k |     e4cv_l | e4cv_omega |   e4cv_chi |   e4cv_phi |   e4cv_tth |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |         1 | 10:45:44.4 |     -0.500 |      0.960 |      1.000 |      0.000 |    -33.988 |    -63.435 |     90.000 |    -67.976 |
# |         2 | 10:45:44.4 |     -0.400 |      0.914 |      1.000 |      0.000 |    -32.583 |    -68.199 |     90.000 |    -65.165 |
# |         3 | 10:45:44.4 |     -0.300 |      0.950 |      1.000 |     -0.000 |    -31.468 |    -73.301 |     90.000 |    -62.935 |
# |         4 | 10:45:44.4 |     -0.200 |      1.018 |      1.000 |     -0.000 |    -30.657 |    -78.690 |     90.000 |    -61.315 |
# |         5 | 10:45:44.5 |     -0.100 |      1.074 |      1.000 |     -0.000 |    -30.165 |    -84.289 |     90.000 |    -60.330 |
# |         6 | 10:45:44.5 |      0.000 |      0.935 |      1.000 |      0.000 |    -30.000 |    -90.000 |     90.000 |    -60.000 |
# |         7 | 10:45:44.5 |      0.100 |      0.909 |      1.000 |      0.000 |    -30.165 |    -95.711 |     90.000 |    -60.330 |
# |         8 | 10:45:44.5 |      0.200 |      0.976 |      1.000 |     -0.000 |    -30.657 |   -101.310 |     90.000 |    -61.315 |
# |         9 | 10:45:44.5 |      0.300 |      0.999 |      1.000 |     -0.000 |    -31.468 |   -106.699 |     90.000 |    -62.935 |
# |        10 | 10:45:44.5 |      0.400 |      0.919 |      1.000 |     -0.000 |    -32.583 |   -111.801 |     90.000 |    -65.165 |
# |        11 | 10:45:44.5 |      0.500 |      1.038 |      1.000 |     -0.000 |    -33.988 |   -116.565 |     90.000 |    -67.976 |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# generator scan ['78c80bd6'] (scan num: 2)
# ('78c80bd6-ebed-45c5-866d-14f05769844f',)

# %% [markdown]
# ## What other modes are available?

# %%
e4cv.operator.solver.modes
# Out:
# ['bissector',
#  'constant_omega',
#  'constant_chi',
#  'constant_phi',
#  'double_diffraction',
#  'psi_constant']

# %% [markdown]
# ## Scan $(h10)$ holding $\omega$ at -30 degrees
#
# Set the mode to `"constant_omega"`, then set $\omega=-30$ degrees.

# %%
e4cv.operator.solver.mode = "constant_omega"
e4cv.omega.move(-30)
print(f"{e4cv.omega.position=!r}")
# Out:
# e4cv.omega.position=-30

# %% [markdown]
# **Run the scan again** with the same command.

# %%
print(f"{e4cv.operator.solver.mode=!r}")
e4cv.k.move(1)
e4cv.l.move(0)
RE(bp.scan([noisy_det, e4cv], e4cv.h, -0.5, 0.5, 11))
# Out:
# e4cv.operator.solver.mode='constant_omega'
#
#
# Transient Scan ID: 3     Time: 2024-07-29 10:45:44
# Persistent Unique Scan ID: 'fc29120e-ea36-4960-b78e-580938dd85ff'
# New stream: 'primary'
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |   seq_num |       time |     e4cv_h |  noisy_det |     e4cv_k |     e4cv_l | e4cv_omega |   e4cv_chi |   e4cv_phi |   e4cv_tth |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |         1 | 10:45:44.7 |     -0.500 |      1.054 |      1.000 |      0.000 |    -30.000 |    -63.714 |     81.054 |    -67.976 |
# |         2 | 10:45:44.7 |     -0.400 |      0.939 |      1.000 |     -0.000 |    -30.000 |    -68.345 |     83.031 |    -65.165 |
# |         3 | 10:45:44.7 |     -0.300 |      1.060 |      1.000 |     -0.000 |    -30.000 |    -73.364 |     84.887 |    -62.935 |
# |         4 | 10:45:44.7 |     -0.200 |      0.919 |      1.000 |     -0.000 |    -30.000 |    -78.709 |     86.647 |    -61.315 |
# |         5 | 10:45:44.7 |     -0.100 |      1.040 |      1.000 |     -0.000 |    -30.000 |    -84.292 |     88.340 |    -60.330 |
# |         6 | 10:45:44.7 |     -0.000 |      0.904 |      1.000 |     -0.000 |    -30.000 |    -90.000 |     88.340 |    -60.000 |
# |         7 | 10:45:44.7 |      0.100 |      0.901 |      1.000 |     -0.000 |    -30.000 |    -95.708 |     91.660 |    -60.330 |
# |         8 | 10:45:44.8 |      0.200 |      0.922 |      1.000 |     -0.000 |    -30.000 |   -101.291 |     93.353 |    -61.315 |
# |         9 | 10:45:44.8 |      0.300 |      1.004 |      1.000 |     -0.000 |    -30.000 |   -106.636 |     95.113 |    -62.935 |
# |        10 | 10:45:44.8 |      0.400 |      0.915 |      1.000 |     -0.000 |    -30.000 |   -111.655 |     96.969 |    -65.165 |
# |        11 | 10:45:44.8 |      0.500 |      1.014 |      1.000 |      0.000 |    -30.000 |   -116.286 |     98.946 |    -67.976 |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# generator scan ['fc29120e'] (scan num: 3)
# ('fc29120e-ea36-4960-b78e-580938dd85ff',)

# %% [markdown]
# ## Scan $(\bar{1}kl)$ holding $\omega$ at -30 degrees
#
# Keep mode as `"constant_omega"` and $\omega=-30$.  Set $h=-1$ and scan $k$ & $l$.

# %%
e4cv.h.move(-1)
print(f"{e4cv.operator.solver.mode=!r}")
RE(bp.scan([noisy_det, e4cv], e4cv.k, 0.9, 1.1, e4cv.l, -0.6, -0.4, 11))
# Out:
# e4cv.operator.solver.mode='constant_omega'
#
#
# Transient Scan ID: 4     Time: 2024-07-29 10:45:44
# Persistent Unique Scan ID: '48c0cf76-361d-435a-935a-ae45562a5c8e'
# New stream: 'primary'
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |   seq_num |       time |     e4cv_k |     e4cv_l |  noisy_det |     e4cv_h | e4cv_omega |   e4cv_chi |   e4cv_phi |   e4cv_tth |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |         1 | 10:45:45.0 |      0.900 |     -0.600 |      1.000 |     -1.000 |    -30.000 |    -39.821 |     36.793 |    -94.876 |
# |         2 | 10:45:45.0 |      0.920 |     -0.580 |      1.038 |     -1.000 |    -30.000 |    -40.796 |     37.124 |    -95.244 |
# |         3 | 10:45:45.0 |      0.940 |     -0.560 |      1.091 |     -1.000 |    -30.000 |    -41.770 |     37.424 |    -95.659 |
# |         4 | 10:45:45.0 |      0.960 |     -0.540 |      0.922 |     -1.000 |    -30.000 |    -42.745 |     37.689 |    -96.119 |
# |         5 | 10:45:45.0 |      0.980 |     -0.520 |      1.019 |     -1.000 |    -30.000 |    -43.721 |     37.920 |    -96.627 |
# |         6 | 10:45:45.0 |      1.000 |     -0.500 |      0.978 |     -1.000 |    -30.000 |    -44.698 |     38.112 |    -97.181 |
# |         7 | 10:45:45.0 |      1.020 |     -0.480 |      0.940 |     -1.000 |    -30.000 |    -45.677 |     38.265 |    -97.782 |
# |         8 | 10:45:45.0 |      1.040 |     -0.460 |      0.905 |     -1.000 |    -30.000 |    -46.660 |     38.375 |    -98.430 |
# |         9 | 10:45:45.1 |      1.060 |     -0.440 |      1.052 |     -1.000 |    -30.000 |    -47.647 |     38.440 |    -99.126 |
# |        10 | 10:45:45.1 |      1.080 |     -0.420 |      0.963 |     -1.000 |    -30.000 |    -48.640 |     38.457 |    -99.869 |
# |        11 | 10:45:45.1 |      1.100 |     -0.400 |      0.904 |     -1.000 |    -30.000 |    -49.641 |     38.422 |   -100.661 |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# generator scan ['48c0cf76'] (scan num: 4)
# ('48c0cf76-361d-435a-935a-ae45562a5c8e',)

# %% [markdown]
# ## Scan $(h10)$ holding $\psi$ at 25 degrees around $(100)$
#
# Set the mode to `"psi_constant"`, then set $h_2=1, k_2=0, l_2=0$ & $\psi=25$ degrees.
#
# TODO: What is $\psi$?  What is $(h_2, k_2, l_2)$?  Is enabled by solver yet?

# %%
e4cv.operator.solver.mode = "psi_constant"

# TODO: Can this be even easier?
extras = {
    "h2": 1,
    "k2": 0,
    "l2": 0,
    "psi": 25,
}
e4cv.operator.solver.extras = extras

# %%
print(f"{e4cv.operator.solver.mode=!r}")
print(f"{e4cv.operator.solver.extras=!r}")
RE(bp.scan([noisy_det, e4cv], e4cv.k, 0.9, 1.1, e4cv.l, -0.6, -0.4, 11))
# Out:
# e4cv.operator.solver.mode='psi_constant'
# e4cv.operator.solver.extras={'h2': 1.0, 'k2': 0.0, 'l2': 0.0, 'psi': 25.0}
#
#
# Transient Scan ID: 5     Time: 2024-07-29 10:45:45
# Persistent Unique Scan ID: '320521d0-e29a-4067-b9d7-dfae2cf0fd77'
# New stream: 'primary'
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |   seq_num |       time |     e4cv_k |     e4cv_l |  noisy_det |     e4cv_h | e4cv_omega |   e4cv_chi |   e4cv_phi |   e4cv_tth |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |         1 | 10:45:45.3 |      0.900 |     -0.600 |      1.036 |     -1.000 |      3.258 |    -74.691 |    -18.768 |    -94.876 |
# |         2 | 10:45:45.3 |      0.920 |     -0.580 |      1.018 |     -1.000 |      2.461 |    -76.033 |    -18.698 |    -95.244 |
# |         3 | 10:45:45.3 |      0.940 |     -0.560 |      0.971 |     -1.000 |      1.635 |    -77.355 |    -18.646 |    -95.659 |
# |         4 | 10:45:45.3 |      0.960 |     -0.540 |      1.030 |     -1.000 |      0.781 |    -78.654 |    -18.611 |    -96.119 |
# |         5 | 10:45:45.3 |      0.980 |     -0.520 |      1.098 |     -1.000 |     -0.104 |    -79.930 |    -18.592 |    -96.627 |
# |         6 | 10:45:45.3 |      1.000 |     -0.500 |      0.978 |     -1.000 |     -1.017 |    -81.181 |    -18.589 |    -97.181 |
# |         7 | 10:45:45.3 |      1.020 |     -0.480 |      1.065 |     -1.000 |     -1.959 |    -82.406 |    -18.599 |    -97.782 |
# |         8 | 10:45:45.3 |      1.040 |     -0.460 |      1.068 |     -1.000 |     -2.930 |    -83.605 |    -18.624 |    -98.430 |
# |         9 | 10:45:45.3 |      1.060 |     -0.440 |      0.938 |     -1.000 |     -3.930 |    -84.776 |    -18.661 |    -99.126 |
# |        10 | 10:45:45.3 |      1.080 |     -0.420 |      1.061 |     -1.000 |     -4.957 |    -85.920 |    -18.709 |    -99.869 |
# |        11 | 10:45:45.3 |      1.100 |     -0.400 |      0.991 |     -1.000 |     -6.014 |    -87.035 |    -18.769 |   -100.661 |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# generator scan ['320521d0'] (scan num: 5)
# ('320521d0-e29a-4067-b9d7-dfae2cf0fd77',)

# %% [markdown]
# ## Scan $\psi$ around $(100)$ with sample oriented at $(101)$
#
# Set the mode to `"psi_constant"`, then set $h_2=1, k_2=0, l_2=0$. Step scan
# $\psi$ through desired range, setting before reporting at each step.

# %%
# from lib_demo_scan import scan_extra_parameter
# %run -im lib_demo_scan
e4cv.wh(full=True)
# Out:
# diffractometer='e4cv'
# Sample(name='sample', lattice=Lattice(a=1, system='cubic'))
# HklSolver(name='hkl_soleil', version='5.0.0.3511', geometry='E4CV', engine_name='hkl', mode='psi_constant')
# wavelength=1.0
# h=-1.0 k=1.1 l=-0.4
# omega=-6.0135 chi=-87.0346 phi=-18.7687 tth=-100.6611
# h2=1.0 k2=0 l2=0 psi=25.0

# %%
print(f"{e4cv.operator.solver.mode=!r}")
RE(
    scan_extra_parameter(
        e4cv,
        detectors=[noisy_det],
        pseudos=(1, 0, 1),
        axis="psi",
        start=4,
        finish=44,
        num=11,
        extras=dict(h2=1, k2=0, l2=0),
    ),
    collector.receiver
)
# Out:
# e4cv.operator.solver.mode='psi_constant'
#
#
# Transient Scan ID: 6     Time: 2024-07-29 10:45:45
# Persistent Unique Scan ID: '4207283c-fc7a-4767-8984-54cbb82ed28a'
# New stream: 'primary'
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |   seq_num |       time |  noisy_det |     e4cv_h |     e4cv_k |     e4cv_l | e4cv_omega |   e4cv_chi |   e4cv_phi |   e4cv_tth |        psi |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# |         1 | 10:45:45.6 |      0.991 |      1.000 |     -0.000 |      1.000 |   -135.000 |   -176.000 |    -45.000 |    -90.000 |      4.000 |
# |         2 | 10:45:45.6 |      0.991 |      1.000 |      0.000 |      1.000 |   -135.000 |   -172.000 |    -45.000 |    -90.000 |      8.000 |
# |         3 | 10:45:45.6 |      0.991 |      1.000 |     -0.000 |      1.000 |   -135.000 |   -168.000 |    -45.000 |    -90.000 |     12.000 |
# |         4 | 10:45:45.6 |      0.991 |      1.000 |      0.000 |      1.000 |   -135.000 |   -164.000 |    -45.000 |    -90.000 |     16.000 |
# |         5 | 10:45:45.6 |      0.991 |      1.000 |      0.000 |      1.000 |   -135.000 |   -160.000 |    -45.000 |    -90.000 |     20.000 |
# |         6 | 10:45:45.6 |      0.991 |      1.000 |     -0.000 |      1.000 |   -135.000 |   -156.000 |    -45.000 |    -90.000 |     24.000 |
# |         7 | 10:45:45.6 |      0.991 |      1.000 |     -0.000 |      1.000 |   -135.000 |   -152.000 |    -45.000 |    -90.000 |     28.000 |
# |         8 | 10:45:45.6 |      0.991 |      1.000 |     -0.000 |      1.000 |   -135.000 |   -148.000 |    -45.000 |    -90.000 |     32.000 |
# |         9 | 10:45:45.6 |      0.991 |      1.000 |      0.000 |      1.000 |   -135.000 |   -144.000 |    -45.000 |    -90.000 |     36.000 |
# |        10 | 10:45:45.6 |      0.991 |      1.000 |     -0.000 |      1.000 |   -135.000 |   -140.000 |    -45.000 |    -90.000 |     40.000 |
# |        11 | 10:45:45.6 |      0.991 |      1.000 |      0.000 |      1.000 |   -135.000 |   -136.000 |    -45.000 |    -90.000 |     44.000 |
# +-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+
# generator scan_extra_parameter ['4207283c'] (scan num: 6)
# ('4207283c-fc7a-4767-8984-54cbb82ed28a',)

# %% [markdown]
# Show all the documents published from this run.

# %%
collector.documents
# Out:
# [('start',
#   {'uid': '4207283c-fc7a-4767-8984-54cbb82ed28a',
#    'time': 1722267945.581714,
#    'versions': {'ophyd': '1.9.0', 'bluesky': '1.13.0a3'},
#    'scan_id': 6,
#    'plan_type': 'generator',
#    'plan_name': 'scan_extra_parameter',
#    'diffractometer': {'name': 'e4cv',
#     'solver': 'hkl_soleil',
#     'geometry': 'E4CV',
#     'engine': 'hkl',
#     'mode': 'psi_constant',
#     'extra_axes': ['h2', 'k2', 'l2', 'psi']},
#    'axis': 'psi',
#    'start': 4,
#    'finish': 44,
#    'num': 11,
#    'pseudos': (1, 0, 1),
#    'reals': None,
#    'extras': {'h2': 1, 'k2': 0, 'l2': 0},
#    'transformation': 'forward'}),
#  ('descriptor',
#   {'configuration': {'noisy_det': {'data': {'noisy_det_Imax': 1,
#       'noisy_det_center': 0,
#       'noisy_det_sigma': 1,
#       'noisy_det_noise': 'uniform',
#       'noisy_det_noise_multiplier': 0.1},
#      'timestamps': {'noisy_det_Imax': 1722267944.1981087,
#       'noisy_det_center': 1722267944.1981025,
#       'noisy_det_sigma': 1722267944.1981163,
#       'noisy_det_noise': 1722267944.1981235,
#       'noisy_det_noise_multiplier': 1722267944.198128},
#      'data_keys': OrderedDict([('noisy_det_Imax',
#                    {'source': 'SIM:noisy_det_Imax',
#                     'dtype': 'integer',
#                     'shape': []}),
#                   ('noisy_det_center',
#                    {'source': 'SIM:noisy_det_center',
#                     'dtype': 'integer',
#                     'shape': []}),
#                   ('noisy_det_sigma',
#                    {'source': 'SIM:noisy_det_sigma',
#                     'dtype': 'integer',
#                     'shape': []}),
#                   ('noisy_det_noise',
#                    {'source': 'SIM:noisy_det_noise',
#                     'dtype': 'integer',
#                     'shape': [],
#                     'enum_strs': ('none', 'poisson', 'uniform')}),
#                   ('noisy_det_noise_multiplier',
#                    {'source': 'SIM:noisy_det_noise_multiplier',
#                     'dtype': 'number',
#                     'shape': []})])},
#     'e4cv': {'data': {'e4cv_geometry': 'E4CV',
#       'e4cv_solver': 'hkl_soleil',
#       'e4cv_wavelength': 1.0},
#      'timestamps': {'e4cv_geometry': 1722267943.7721956,
#       'e4cv_solver': 1722267943.7722116,
#       'e4cv_wavelength': 1722267943.772224},
#      'data_keys': OrderedDict([('e4cv_geometry',
#                    {'source': 'PY:e4cv.operator.geometry',
#                     'dtype': 'string',
#                     'shape': []}),
#                   ('e4cv_solver',
#                    {'source': 'PY:e4cv.solver_name',
#                     'dtype': 'string',
#                     'shape': []}),
#                   ('e4cv_wavelength',
#                    {'source': 'PY:e4cv._wavelength.wavelength',
#                     'dtype': 'number',
#                     'shape': []})])},
#     'psi': {'data': {'psi': 4.0},
#      'timestamps': {'psi': 1722267945.5927231},
#      'data_keys': {'psi': {'source': 'SIM:psi',
#        'dtype': 'number',
#        'shape': []}}}},
#    'data_keys': {'noisy_det': {'source': 'SIM:noisy_det',
#      'dtype': 'number',
#      'shape': [],
#      'precision': 3,
#      'object_name': 'noisy_det'},
#     'e4cv_h': {'source': 'PY:e4cv_h.position',
#      'dtype': 'number',
#      'shape': [],
#      'upper_ctrl_limit': 0,
#      'lower_ctrl_limit': 0,
#      'units': '',
#      'object_name': 'e4cv'},
#     'e4cv_h_setpoint': {'source': 'PY:e4cv_h.target',
#      'dtype': 'integer',
#      'shape': [],
#      'upper_ctrl_limit': 0,
#      'lower_ctrl_limit': 0,
#      'units': '',
#      'object_name': 'e4cv'},
#     'e4cv_k': {'source': 'PY:e4cv_k.position',
#      'dtype': 'number',
#      'shape': [],
#      'upper_ctrl_limit': 0,
#      'lower_ctrl_limit': 0,
#      'units': '',
#      'object_name': 'e4cv'},
#     'e4cv_k_setpoint': {'source': 'PY:e4cv_k.target',
#      'dtype': 'number',
#      'shape': [],
#      'upper_ctrl_limit': 0,
#      'lower_ctrl_limit': 0,
#      'units': '',
#      'object_name': 'e4cv'},
#     'e4cv_l': {'source': 'PY:e4cv_l.position',
#      'dtype': 'number',
#      'shape': [],
#      'upper_ctrl_limit': 0,
#      'lower_ctrl_limit': 0,
#      'units': '',
#      'object_name': 'e4cv'},
#     'e4cv_l_setpoint': {'source': 'PY:e4cv_l.target',
#      'dtype': 'number',
#      'shape': [],
#      'upper_ctrl_limit': 0,
#      'lower_ctrl_limit': 0,
#      'units': '',
#      'object_name': 'e4cv'},
#     'e4cv_omega': {'source': 'computed',
#      'dtype': 'number',
#      'shape': [],
#      'units': '',
#      'lower_ctrl_limit': -180,
#      'upper_ctrl_limit': 180,
#      'object_name': 'e4cv'},
#     'e4cv_chi': {'source': 'computed',
#      'dtype': 'number',
#      'shape': [],
#      'units': '',
#      'lower_ctrl_limit': -180,
#      'upper_ctrl_limit': 180,
#      'object_name': 'e4cv'},
#     'e4cv_phi': {'source': 'computed',
#      'dtype': 'number',
#      'shape': [],
#      'units': '',
#      'lower_ctrl_limit': -180,
#      'upper_ctrl_limit': 180,
#      'object_name': 'e4cv'},
#     'e4cv_tth': {'source': 'computed',
#      'dtype': 'number',
#      'shape': [],
#      'units': '',
#      'lower_ctrl_limit': -170,
#      'upper_ctrl_limit': 170,
#      'object_name': 'e4cv'},
#     'psi': {'source': 'SIM:psi',
#      'dtype': 'number',
#      'shape': [],
#      'object_name': 'psi'}},
#    'name': 'primary',
#    'object_keys': {'noisy_det': ['noisy_det'],
#     'e4cv': ['e4cv_h',
#      'e4cv_h_setpoint',
#      'e4cv_k',
#      'e4cv_k_setpoint',
#      'e4cv_l',
#      'e4cv_l_setpoint',
#      'e4cv_omega',
#      'e4cv_chi',
#      'e4cv_phi',
#      'e4cv_tth'],
#     'psi': ['psi']},
#    'run_start': '4207283c-fc7a-4767-8984-54cbb82ed28a',
#    'time': 1722267945.6110752,
#    'uid': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815',
#    'hints': {'noisy_det': {'fields': ['noisy_det']},
#     'e4cv': {'fields': ['e4cv_h',
#       'e4cv_k',
#       'e4cv_l',
#       'e4cv_omega',
#       'e4cv_chi',
#       'e4cv_phi',
#       'e4cv_tth']},
#     'psi': {'fields': ['psi']}}}),
#  ('event',
#   {'uid': 'b97b4704-bed4-41b8-95a3-322cbc22cc6a',
#    'time': 1722267945.6288772,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 0.999999999399,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': -3.15e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 1.000000000115,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -135.000000169237,
#     'e4cv_chi': -175.999999989453,
#     'e4cv_phi': -45.000000203251,
#     'e4cv_tth': -89.999999972101,
#     'psi': 4.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6082811,
#     'e4cv_chi': 1722267945.608288,
#     'e4cv_phi': 1722267945.6082928,
#     'e4cv_tth': 1722267945.6082976,
#     'psi': 1722267945.5927231},
#    'seq_num': 1,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': 'c94afded-9fb9-44bb-a2ab-44805363cc32',
#    'time': 1722267945.6382146,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 1.000000000469,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': 6.17e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 1.000000000393,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -134.999999845142,
#     'e4cv_chi': -171.999999955516,
#     'e4cv_phi': -44.999999819998,
#     'e4cv_tth': -90.000000049412,
#     'psi': 8.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.63792,
#     'e4cv_chi': 1722267945.637924,
#     'e4cv_phi': 1722267945.6379268,
#     'e4cv_tth': 1722267945.63793,
#     'psi': 1722267945.6310284},
#    'seq_num': 2,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': '740ed1ae-4d68-4300-bfe1-a93084dd3288',
#    'time': 1722267945.645601,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 0.999999999956,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': -4.08e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 1.000000000044,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -135.000000079496,
#     'e4cv_chi': -167.999999866946,
#     'e4cv_phi': -45.000000080278,
#     'e4cv_tth': -90.0,
#     'psi': 12.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6453733,
#     'e4cv_chi': 1722267945.6453767,
#     'e4cv_phi': 1722267945.6453793,
#     'e4cv_tth': 1722267945.6453817,
#     'psi': 1722267945.6403382},
#    'seq_num': 3,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': '7149f274-e412-4e3a-b2ab-103595fd0269',
#    'time': 1722267945.6518295,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 1.000000000926,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': 1.46e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 1.000000000881,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -135.000000030239,
#     'e4cv_chi': -163.999999916887,
#     'e4cv_phi': -44.999999977994,
#     'e4cv_tth': -90.000000103529,
#     'psi': 16.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6516306,
#     'e4cv_chi': 1722267945.6516335,
#     'e4cv_phi': 1722267945.6516354,
#     'e4cv_tth': 1722267945.6516373,
#     'psi': 1722267945.6473205},
#    'seq_num': 4,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': '8e06e153-c8d6-4a00-8ad3-ed45dc08a89a',
#    'time': 1722267945.6578987,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 1.000000000925,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': 0,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 1.000000000925,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -135.000000053027,
#     'e4cv_chi': -159.999999971042,
#     'e4cv_phi': -45.0,
#     'e4cv_tth': -90.000000106054,
#     'psi': 20.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6577127,
#     'e4cv_chi': 1722267945.657715,
#     'e4cv_phi': 1722267945.6577175,
#     'e4cv_tth': 1722267945.6577194,
#     'psi': 1722267945.6534114},
#    'seq_num': 5,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': '5557b140-c418-4acd-9cef-98085579ef34',
#    'time': 1722267945.6634862,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 0.999999999505,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': -1.36e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 0.999999999072,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -134.999999972824,
#     'e4cv_chi': -155.999999985058,
#     'e4cv_phi': -45.0,
#     'e4cv_tth': -89.999999918471,
#     'psi': 24.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6633036,
#     'e4cv_chi': 1722267945.6633062,
#     'e4cv_phi': 1722267945.6633081,
#     'e4cv_tth': 1722267945.6633098,
#     'psi': 1722267945.659396},
#    'seq_num': 6,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': '6062c223-f683-4b6b-8ce5-4806a09ff5f6',
#    'time': 1722267945.6694927,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 0.999999999984,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': -1.95e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 0.999999999043,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -134.999999988933,
#     'e4cv_chi': -151.999999981706,
#     'e4cv_phi': -44.999999987886,
#     'e4cv_tth': -89.999999944253,
#     'psi': 28.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6693122,
#     'e4cv_chi': 1722267945.6693149,
#     'e4cv_phi': 1722267945.6693165,
#     'e4cv_tth': 1722267945.6693182,
#     'psi': 1722267945.665359},
#    'seq_num': 7,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': 'fbe3920e-853c-46f3-8a8f-b4072bde0734',
#    'time': 1722267945.6750998,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 1.000000000452,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': -1.24e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 1.000000000547,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -135.000000038118,
#     'e4cv_chi': -148.00000003013,
#     'e4cv_phi': -45.000000010772,
#     'e4cv_tth': -90.000000057214,
#     'psi': 32.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6748447,
#     'e4cv_chi': 1722267945.6748476,
#     'e4cv_phi': 1722267945.6748493,
#     'e4cv_tth': 1722267945.6748514,
#     'psi': 1722267945.6708949},
#    'seq_num': 8,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': '9a0bddca-30ee-4909-98a1-a19e9700c571',
#    'time': 1722267945.6810298,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 0.999999999991,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': 1.85e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 1.000000001035,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -135.000000016623,
#     'e4cv_chi': -143.999999972978,
#     'e4cv_phi': -45.000000019602,
#     'e4cv_tth': -90.00000005876,
#     'psi': 36.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6808696,
#     'e4cv_chi': 1722267945.6808722,
#     'e4cv_phi': 1722267945.6808736,
#     'e4cv_tth': 1722267945.6808755,
#     'psi': 1722267945.6768785},
#    'seq_num': 9,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': '81c83876-6c9a-4e6a-997c-59a0590a50b0',
#    'time': 1722267945.6870415,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 0.99999999994,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': -1.17e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 1.00000000006,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -135.000000007347,
#     'e4cv_chi': -139.999999974084,
#     'e4cv_phi': -45.000000009081,
#     'e4cv_tth': -90.0,
#     'psi': 40.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6868267,
#     'e4cv_chi': 1722267945.6868298,
#     'e4cv_phi': 1722267945.686832,
#     'e4cv_tth': 1722267945.6868334,
#     'psi': 1722267945.6825068},
#    'seq_num': 10,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('event',
#   {'uid': '2a9d3164-8786-4165-8c82-d23a7e8dba20',
#    'time': 1722267945.697664,
#    'data': {'noisy_det': 0.9914172247089457,
#     'e4cv_h': 1.000000000676,
#     'e4cv_h_setpoint': -1,
#     'e4cv_k': 2.24e-10,
#     'e4cv_k_setpoint': 1.1,
#     'e4cv_l': 1.000000000408,
#     'e4cv_l_setpoint': -0.4,
#     'e4cv_omega': -135.000000017972,
#     'e4cv_chi': -135.999999949146,
#     'e4cv_phi': -44.999999982917,
#     'e4cv_tth': -90.000000062118,
#     'psi': 44.0},
#    'timestamps': {'noisy_det': 1722267945.3946135,
#     'e4cv_h': 1722267943.77197,
#     'e4cv_h_setpoint': 1722267943.77199,
#     'e4cv_k': 1722267943.7720666,
#     'e4cv_k_setpoint': 1722267943.772079,
#     'e4cv_l': 1722267943.7721512,
#     'e4cv_l_setpoint': 1722267943.7721653,
#     'e4cv_omega': 1722267945.6974528,
#     'e4cv_chi': 1722267945.6974554,
#     'e4cv_phi': 1722267945.6974573,
#     'e4cv_tth': 1722267945.6974595,
#     'psi': 1722267945.68872},
#    'seq_num': 11,
#    'filled': {},
#    'descriptor': 'b2ab0c0c-a8fb-4485-8c6e-2beb2c7c2815'}),
#  ('stop',
#   {'uid': 'caf8d84d-ff3c-44e3-ba07-bd4e6ef5c58f',
#    'time': 1722267945.6990013,
#    'run_start': '4207283c-fc7a-4767-8984-54cbb82ed28a',
#    'exit_status': 'success',
#    'reason': '',
#    'num_events': {'primary': 11}})]
